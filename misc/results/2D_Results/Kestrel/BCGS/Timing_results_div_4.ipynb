# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <hr style="border-width:3px; border-color:coral"/>
# # Timing results for pressure Poisson solver
# <hr style="border-width:3px; border-color:coral"/>
#
#
# Two solver types are reported. In the full matrix system, the discretized system $A\mathbf x = \mathbf b$ is solved. In the Schur complement system, a linear system for the interface values is solved, and a fast FFT-based solver is used for patch solves.  In either the Full or the Schur approaches, GMRES is used as the basic solver (from HYPRE?) along with an an AMG pre-conditioner from HYPRE (BoomerAMG).
#
# Both simulations reported below are then
# * Full matrix with HYPRE used as the pre-conditioner for the full system. [Full matrix (HYPRE)](#fullhypre)
# * Schur matrix with HYPRE used as the pre-conditioner for the Schur complement system. [Schur matrix (HYPRE)](#schurhypre)
#
# We also include comparisions between HYPRE and the Schur matrix approach [here](#comparisons).
# <hr style="border-width:3px; border-color:coral"/>

# %% [markdown]
# ## Read in spreadsheet data
#
# This is set up to read the "div 2" data.  To read data from other runs, change the four statements below from   "(2)" to "(3)" or "(4)".
#
# **Note:** Data may not yet be available in the spreadsheet for these other cases.

# %%
# %reload_ext autoreload
# %autoreload 2

from results_output import *

# %%
timing_results = pd.read_excel("Timing_results.xlsx",sheet_name=None)
div_factor = 4
df_full_hypre  = timing_results["full_hypre ({:d})".format(div_factor)]
df_schur_hypre = timing_results["schur_hypre ({:d})".format(div_factor)]


# For HYPRE results
cols_setup_hypre = ['matrix_setup','hypre_setup']
df_full_hypre['complete_setup'] = df_full_hypre[cols_setup_hypre].sum(axis=1)
df_schur_hypre['complete_setup'] = df_schur_hypre[cols_setup_hypre].sum(axis=1)


cols_solve_full =['linsolve']
cols_solve_schur = ['linsolve','patch_solve']

# %% [markdown]
# <a id='fullhypre'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Full matrix (HYPRE)
# <hr style="border-width:3px; border-color:coral"/>

# %%
import seaborn as sns
cm = sns.light_palette("blue", as_cmap=True)

styler = print_table(df_full_hypre,display_table=False);

# Apply gradient coloring;  use low=, high= to extend domain to [xmin-low*(xmax-xmin),xmax+high*(xmax-xmin)]; defaults=0
styler.background_gradient(subset=['complete_solve','complete_setup'],cmap=cm,low=0,high=0.7)
# Out:
# /home/brenton/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:489: RuntimeWarning: invalid value encountered in less
#   np.copyto(xa, -1, where=xa < 0.0)
# <style  type="text/css" >
#     #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col4 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col5 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col6 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col7 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col8 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col9 {
#             width:  100px;
#             background-color:  #5e5eff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col10 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row0_col11 {
#             width:  100px;
#             background-color:  #e3e3ff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col4 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col5 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col6 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col7 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col8 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col9 {
#             width:  100px;
#             background-color:  #e5e5ff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col10 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row1_col11 {
#             width:  100px;
#             background-color:  #e5e5ff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col4 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col5 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col6 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col7 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col8 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col9 {
#             width:  100px;
#             background-color:  #d6d6ff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col10 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row2_col11 {
#             width:  100px;
#             background-color:  #5e5eff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col4 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col5 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col6 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col7 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col8 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col9 {
#             width:  100px;
#             background-color:  #6464ff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col10 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row3_col11 {
#             width:  100px;
#             background-color:  #b6b6ff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col4 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col5 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col6 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col7 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col8 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col9 {
#             width:  100px;
#             background-color:  #dbdbff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col10 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row4_col11 {
#             width:  100px;
#             background-color:  #d8d8ff;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row5_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row5_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row5_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row5_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row5_col4 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row5_col5 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row5_col6 {
#             width:  100px;
#         }    #T_796125ce_3bfc_11e8_aa5f_000c29b65823row5_col7 {
#             width:  100px;
#         }    #T_796125ce_3bfc

# %% [markdown]
# ## Full matrix (HYPRE) : Setup

# %%
barh_plot(df_full_hypre,cols_setup_hypre)
plt.title('Full matrix (setup)',fontsize=16);
set_xticks(20,5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Solve

# %%
bar_plot(df_full_hypre,cols_solve_full)
plt.title('Full solve (HYPRE)',fontsize=16);
set_xticks(5,2.5)
plt.xlim([0,20])
plt.xlabel('Time (seconds)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Strong scaling

# %%
strong_scaling(df_full_hypre,field='complete_solve')
plt.title('Full matrix (HYPRE) : Solve');
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/brenton/research/pressurePoissonSolver/results/2D_Results/Kestrel/BCGS/results_output.py:72: RankWarning: Polyfit may be poorly conditioned
#   c = np.polyfit(np.log(procs[:-2]),np.log(t_strong[:-2]),1)

# %% [markdown]
# ## Full matrix (HYPRE) : Efficiency

# %%
efficiency(df_full_hypre,'complete_solve')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='schurhypre'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Schur matrix (HYPRE)
# <hr style="border-width:3px; border-color:coral"/>

# %%
styler = print_table(df_schur_hypre,display_table=False);

# Apply gradient coloring;  use low=, high= to extend domain to [xmin-low*(xmax-xmin),xmax+high*(xmax-xmin)]; defaults=0
styler.background_gradient(subset=['complete_solve','complete_setup'],cmap=cm,low=0,high=0.5)
# Out:
# <style  type="text/css" >
#     #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col4 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col5 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col6 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col7 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col8 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col9 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col10 {
#             width:  100px;
#             background-color:  #4d4dff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row0_col11 {
#             width:  100px;
#             background-color:  #4d4dff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col4 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col5 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col6 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col7 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col8 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col9 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col10 {
#             width:  100px;
#             background-color:  #a2a2ff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row1_col11 {
#             width:  100px;
#             background-color:  #9696ff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col4 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col5 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col6 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col7 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col8 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col9 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col10 {
#             width:  100px;
#             background-color:  #b1b1ff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row2_col11 {
#             width:  100px;
#             background-color:  #bbbbff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col4 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col5 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col6 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col7 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col8 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col9 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col10 {
#             width:  100px;
#             background-color:  #d7d7ff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row3_col11 {
#             width:  100px;
#             background-color:  #d3d3ff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col4 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col5 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col6 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col7 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col8 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col9 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col10 {
#             width:  100px;
#             background-color:  #dadaff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row4_col11 {
#             width:  100px;
#             background-color:  #ddddff;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row5_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row5_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row5_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row5_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row5_col4 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row5_col5 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row5_col6 {
#             width:  100px;
#         }    #T_796125cf_3bfc_11e8_aa5f_000c29b65823row5_col7 {
#             width:  100px;
#         }    #T_796125cf_3bfc

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup
#
# Use HYPRE to solve the Schur complement system

# %%
barh_plot(df_schur_hypre,cols_setup_hypre)
plt.title('Schur matrix (HYPRE) : Setup',fontsize=16);
set_xticks(2,1,fmt='{:.1f}'.format)
plt.xlim([0,7.5]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Strong scaling (setup)

# %%
strong_scaling(df_schur_hypre,field='complete_setup')
plt.title('Schur matrix (HYPRE) : Strong scaling (setup)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup

# %%
efficiency(df_schur_hypre,'complete_setup')
plt.title('Schur matrix (HYPRE) : Efficiency (%)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Solve

# %%
barh_plot(df_schur_hypre,cols_solve_schur)

plt.title('Schur matrix (HYPRE) : solve',fontsize=16);
set_xticks(2,1,fmt='{:.1f}'.format)

plt.xlim([0,7.5]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Strong scaling (solve)

# %%
strong_scaling(df_schur_hypre,field='complete_solve')
plt.title('Schur matrix (HYPRE) : Strong scaling (solve)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup vs solve time

# %%
bar_plot(df_schur_hypre,['complete_solve','complete_setup'])

plt.xlim([0,7.5])
plt.title('Schur matrix (HYPRE) : Setup vs. solve',fontsize=16);
set_xticks(2,1)
plt.grid(b=True,which='major')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Efficiency

# %%
efficiency(df_schur_hypre,'complete_solve')
plt.title('Schur matrix (HYPRE) : Efficiency (solve)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='comparisons'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Comparisons between full and Schur systems
# <hr style="border-width:3px; border-color:coral"/>

# %%
panel = pd.Panel({'Full (HYPRE)' : df_full_hypre, 'Schur (HYPRE)' : df_schur_hypre})
procs = df_full_hypre['p']

# %% [markdown]
# ## Comparisons : Setup

# %%
df_setup = panel.minor_xs('complete_setup')
df_setup.insert(0,'p',procs)
df_setup
# Out:
#     p Full (HYPRE)  Schur (HYPRE)
# 0   1      63.1296      38.377849
# 1   2            0      20.682634
# 2   4      3077.65      11.888241
# 3   8      1093.87       6.136745
# 4  16      312.844       3.852598
# 5  32      85.9192       2.192629
# 6  64       27.245       1.721771

# %%
df_setup.plot(x='p',logx=True,logy=True,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Setup time',fontsize=16);
fix_xticks(df_setup['p'].values)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_setup,cols=cols)
plt.title("Timing (setup)", fontsize=16);
set_xticks(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_setup,cols=cols)
plt.title("Timing (setup)", fontsize=16);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Comparisons : Solve

# %%
df_solve = panel.minor_xs('complete_solve')
df_solve.insert(0,'p',procs)
df_solve
# Out:
#     p Full (HYPRE)  Schur (HYPRE)
# 0   1      600.174     120.380662
# 1   2          NaN      55.612161
# 2   4      82.2592      44.166834
# 3   8      576.496      16.034005
# 4  16        59.41      13.806137
# 5  32      68.7334      11.350269
# 6  64      12.3298       4.546742

# %%
cols = ['p','Full (HYPRE)','Schur (HYPRE)']
df_solve[cols].plot(x='p',logx=True,logy=False,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Solve time (HYPRE)',fontsize=16);
fix_xticks(df_solve['p'].values)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols=['Full (HYPRE)','Schur (HYPRE)']
bar_plot(df_solve,cols=cols)
plt.title("Timing (solve)", fontsize=16);
set_xticks(5,2.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
