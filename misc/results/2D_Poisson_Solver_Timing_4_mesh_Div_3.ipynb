# %% [markdown]
# # Timing results for 2D Pressure Poisson Solver
# These are the results for the different methods of solving this matrix on a 4 level mesh with the divide 3 option and strong scaling.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import seaborn as sns
cm = sns.light_palette("green", as_cmap=True)

# %% [markdown]
# # Full Matrix with Hypre (1)
# This section is the timing results for solving the full matrix with a 4 level mesh using Hypre. This matrix has 2,129,920 degrees of freedom.

# %%
DOF = 8519680
Petsc_Hypre_Full_Cores = np.array([1,2,4,8,16,32,64])
Petsc_Hypre_Full_Iterations = np.array([27,25,26,26,25,25,25])
Petsc_Hypre_Full_Residual = np.array([5.9988067127624e-10,1.4273238491268e-10,1.7254957978808e-10,9.5011690618987e-11,
                                     4.1219666250785e-10,2.1063728799053e-10,4.8227291436170e-10])
Petsc_Hypre_Full_Error = np.array([2.3017137287093e-04,2.3017137246889e-04,2.3017137270920e-04,2.3017137270801e-04,
                                  2.3017137247438e-04,2.3017137244399e-04,2.3017137247297e-04])
Petsc_Hypre_Full_Domain = np.array([2.3153894807,1.2637218663,0.6478832577,0.3401489734,0.1812644858,0.0898693553,
                                   0.0617126075])
Petsc_Hypre_Full_Matrix = np.array([3.3369409704,2.0570431213,1.0631297091,0.5936307549,0.3467149461,0.161736464,
                                   0.0923267154])
Petsc_Hypre_Full_Petsc = np.array([10.3979734503,391.6720703532,186.4258577879,71.9993323065,21.9934946754,
                                  6.5406074993,2.8195007452])
Petsc_Hypre_Full_LSS = np.array([13.7349249107,393.7291275882,187.4890104319,72.5929859406,22.3402330636,6.7023960359,
                                2.9118931858])
Petsc_Hypre_Full_LinS = np.array([68.0680552959,40.4927748359,29.4081339507,24.11662926,17.5557686602,10.2702540602,
                                 8.4260292341])
Petsc_Hypre_Full_CS = np.array([68.0680601461,40.4927931763,29.408291536,24.1182497637,17.5584340833,10.2716404851,
                               8.4316525948])
Petsc_Hypre_Full_DegF = (DOF)/Petsc_Hypre_Full_CS/Petsc_Hypre_Full_Cores
Petsc_Hypre_Full_Eff = Petsc_Hypre_Full_CS[0]/(Petsc_Hypre_Full_CS*Petsc_Hypre_Full_Cores)

d = {"Cores": Petsc_Hypre_Full_Cores,"Iterations": Petsc_Hypre_Full_Iterations,"Residual": Petsc_Hypre_Full_Residual,
    "Error": Petsc_Hypre_Full_Error,"Domain Initialization": Petsc_Hypre_Full_Domain,"Matrix Formation": Petsc_Hypre_Full_Matrix,
    "Hypre Setup": Petsc_Hypre_Full_Petsc,"Linear System Setup": Petsc_Hypre_Full_LSS,"Linear Solve": Petsc_Hypre_Full_LinS,
    "Complete Solve": Petsc_Hypre_Full_CS,"Efficiency": Petsc_Hypre_Full_Eff,"Degrees of Freedom Per Time Per Core": Petsc_Hypre_Full_DegF}
df1 =  pd.DataFrame(data = d)
df1 = df1[["Cores","Iterations","Residual","Error","Domain Initialization","Matrix Formation","Hypre Setup",
         "Linear System Setup","Linear Solve","Complete Solve","Efficiency","Degrees of Freedom Per Time Per Core"]]
nform = {"Error" : "{:6.2e}".format, "Residual" : "{:6.2e}".format}

df1.style.set_caption("Degrees of freedom {:,}".format(DOF)).background_gradient(cmap=cm).format(nform)
# display(HTML(df1.to_html(index=False)))
# Out:
# <style  type="text/css" >
#     #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col1 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col2 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col3 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col4 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col5 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col6 {
#             background-color:  #e2fde2;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col7 {
#             background-color:  #dffcdf;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col8 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col9 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col10 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row0_col11 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col0 {
#             background-color:  #e2fde2;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col2 {
#             background-color:  #d0f3d0;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col3 {
#             background-color:  #d9f8d9;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col4 {
#             background-color:  #6bbb6b;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col5 {
#             background-color:  #5ab25a;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col6 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col7 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col8 {
#             background-color:  #6abb6a;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col9 {
#             background-color:  #6abb6a;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col10 {
#             background-color:  #299729;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row1_col11 {
#             background-color:  #299729;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col0 {
#             background-color:  #dbf9db;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col1 {
#             background-color:  #72bf72;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col2 {
#             background-color:  #c2ecc2;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col3 {
#             background-color:  #56b056;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col4 {
#             background-color:  #aadeaa;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col5 {
#             background-color:  #a1d9a1;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col6 {
#             background-color:  #7ac37a;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col7 {
#             background-color:  #7ac37a;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col8 {
#             background-color:  #94d294;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col9 {
#             background-color:  #94d294;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col10 {
#             background-color:  #6fbd6f;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row2_col11 {
#             background-color:  #6fbd6f;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col0 {
#             background-color:  #ccf1cc;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col1 {
#             background-color:  #72bf72;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col3 {
#             background-color:  #57b057;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col4 {
#             background-color:  #caf0ca;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col5 {
#             background-color:  #c2ecc2;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col6 {
#             background-color:  #bde9bd;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col7 {
#             background-color:  #bde9bd;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col8 {
#             background-color:  #a9dea9;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col9 {
#             background-color:  #a9dea9;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col10 {
#             background-color:  #aadeaa;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row3_col11 {
#             background-color:  #aadeaa;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col0 {
#             background-color:  #b0e1b0;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col2 {
#             background-color:  #56af56;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col3 {
#             background-color:  #d5f6d5;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col4 {
#             background-color:  #daf9da;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col5 {
#             background-color:  #d3f5d3;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col6 {
#             background-color:  #dbf9db;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col7 {
#             background-color:  #dbf9db;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col8 {
#             background-color:  #c2ecc2;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col9 {
#             background-color:  #c2ecc2;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col10 {
#             background-color:  #c7eec7;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row4_col11 {
#             background-color:  #c7eec7;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col0 {
#             background-color:  #75c175;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col2 {
#             background-color:  #b1e2b1;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col4 {
#             background-color:  #e3fee3;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col5 {
#             background-color:  #e1fde1;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col6 {
#             background-color:  #e4fee4;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col7 {
#             background-color:  #e4fee4;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col8 {
#             background-color:  #dffcdf;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col9 {
#             background-color:  #dffcdf;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col10 {
#             background-color:  #d1f4d1;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row5_col11 {
#             background-color:  #d1f4d1;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row6_col0 {
#             background-color:  #008000;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row6_col2 {
#             background-color:  #359d35;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row6_col3 {
#             background-color:  #d6f7d6;
#         }    #T_d0c5b0bc_2312_11e8_b8df_000c29b65823row6_col4 {

# %%
DOF = 8519680
Petsc_Hypre_Full_Cores = np.array([1,2,4,8,16,32,64])
Petsc_Hypre_Full_Iterations = np.array([27,25,26,26,25,25,25])
Petsc_Hypre_Full_Residual = np.array([5.9988067127624e-10,1.4273238491268e-10,1.7254957978808e-10,9.5011690618987e-11,
                                     4.1219666250785e-10,2.1063728799053e-10,4.8227291436170e-10])
Petsc_Hypre_Full_Error = np.array([2.3017137287093e-04,2.3017137246889e-04,2.3017137270920e-04,2.3017137270801e-04,
                                  2.3017137247438e-04,2.3017137244399e-04,2.3017137247297e-04])
Petsc_Hypre_Full_Domain = np.array([2.3153894807,1.2637218663,0.6478832577,0.3401489734,0.1812644858,0.0898693553,
                                   0.0617126075])
Petsc_Hypre_Full_Matrix = np.array([3.3369409704,2.0570431213,1.0631297091,0.5936307549,0.3467149461,0.161736464,
                                   0.0923267154])
Petsc_Hypre_Full_Petsc = np.array([10.3979734503,391.6720703532,186.4258577879,71.9993323065,21.9934946754,
                                  6.5406074993,2.8195007452])
Petsc_Hypre_Full_LSS = np.array([13.7349249107,393.7291275882,187.4890104319,72.5929859406,22.3402330636,6.7023960359,
                                2.9118931858])
Petsc_Hypre_Full_LinS = np.array([68.0680552959,40.4927748359,29.4081339507,24.11662926,17.5557686602,10.2702540602,
                                 8.4260292341])
Petsc_Hypre_Full_CS = np.array([68.0680601461,40.4927931763,29.408291536,24.1182497637,17.5584340833,10.2716404851,
                               8.4316525948])
Initialization = Petsc_Hypre_Full_Domain + Petsc_Hypre_Full_Matrix + Petsc_Hypre_Full_Petsc + Petsc_Hypre_Full_LSS

Petsc_Hypre_Full_Eff = Petsc_Hypre_Full_CS[0]/(Petsc_Hypre_Full_CS*Petsc_Hypre_Full_Cores)

d = {"Cores": Petsc_Hypre_Full_Cores,"Iterations": Petsc_Hypre_Full_Iterations,"Residual": Petsc_Hypre_Full_Residual,
    "Error": Petsc_Hypre_Full_Error,"Initialization": Initialization,"Linear Solve": Petsc_Hypre_Full_LinS,
    "Complete Solve": Petsc_Hypre_Full_CS,"Efficiency": Petsc_Hypre_Full_Eff}
df1 =  pd.DataFrame(data = d)
df1 = df1[["Cores","Iterations","Initialization","Complete Solve","Residual","Error","Efficiency"]]
nform = {"Error" : "{:6.2e}".format, "Residual" : "{:6.2e}".format}

display(HTML(df1.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Cores</th>
#       <th>Iterations</th>
#       <th>Initialization</th>
#       <th>Complete Solve</th>
#       <th>Residual</th>
#       <th>Error</th>
#       <th>Efficiency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>27</td>
#       <td>29.785229</td>
#       <td>68.068060</td>
#       <td>5.998807e-10</td>
#       <td>0.00023</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>25</td>
#       <td>788.721963</td>
#       <td>40.492793</td>
#       <td>1.427324e-10</td>
#       <td>0.00023</td>
#       <td>0.840496</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>26</td>
#       <td>375.625881</td>
#       <td>29.408292</td>
#       <td>1.725496e-10</td>
#       <td>0.00023</td>
#       <td>0.578647</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>26</td>
#       <td>145.526098</td>
#       <td>24.118250</td>
#       <td>9.501169e-11</td>
#       <td>0.00023</td>
#       <td>0.352783</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>25</td>
#       <td>44.861707</td>
#       <td>17.558434</td>
#       <td>4.121967e-10</td>
#       <td>0.00023</td>
#       <td>0.242291</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>25</td>
#       <td>13.494609</td>
#       <td>10.271640</td>
#       <td>2.106373e-10</td>
#       <td>0.00023</td>
#       <td>0.207087</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>25</td>
#       <td>5.885433</td>
#       <td>8.431653</td>
#       <td>4.822729e-10</td>
#       <td>0.00023</td>
#       <td>0.126139</td>
#     </tr>
#   </tbody>
# </table>

# %%
x = Petsc_Hypre_Full_Cores
y = Petsc_Hypre_Full_CS


plt.plot(x,y,"bo-",label="Hypre (Full matrix)")
plt.yscale("log")
plt.xscale("log")
plt.ylabel("Complete Solve Time (s)")
plt.xlabel("Number of Cores")
plt.title("Full Matrix with 4 level mesh using Hypre")

c = np.polyfit(np.log(x),np.log(y),1)
#  c = np.polyfit(np.log(x[:-2]),np.log(y[-2]),1)
#  Take out points for slope

s = "Best-fit (slope = {:6.2f})".format(c[0])
plt.loglog(x,np.exp(np.polyval(c,np.log(x))),'k--',label=s)

ct = np.array([-1,c[1]])
plt.loglog(x,np.exp(np.polyval(ct,np.log(x))),'.-',label="Theoretical",color='k',markersize=10)


plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(Petsc_Hypre_Full_Cores,Petsc_Hypre_Full_DegF,"ro-",label="Full")
plt.ylabel("Degrees of Freedom Per Time Per Core")
plt.xlabel("Number of Cores")
plt.title("Full Matrix with 4 level mesh using Hypre")
plt.legend()

# %% [markdown]
# # Full Matrix with AMGX (2)
# This section is the timing results for solving the full matrix using AMGX. This matrix has 8,519,680 degrees of freedom.
#
# Was not able to get results on 1 or 2 cores. I got a memory error.

# %%
DOF = 8519680
Petsc_AMGX_Full_Cores = np.array([4,8,16])
Petsc_AMGX_Full_Iterations = np.array([53,54,100])
Petsc_AMGX_Full_Residual = np.array([2.6928778673549e-11,2.5390739248273e-11,4.4980646373830e+34])
Petsc_AMGX_Full_Error = np.array([2.3017137276764e-04,2.3017137259899e-04,2.5162658115142e+32])
Petsc_AMGX_Full_Domain = np.array([0.6384049258,0.3250950618,0.1596760514])
Petsc_AMGX_Full_Matrix = np.array([1.0501234819,0.5264085192,0.25415168])
Petsc_AMGX_Full_AMGX = np.array([5.8601402815,4.7022465706,3.3320006146])
Petsc_AMGX_Full_LSS = np.array([6.9102868591,5.2286880751,3.5861939082])
Petsc_AMGX_Full_LinS = np.array([3.168793774,2.4353946755,3.4660941007])
Petsc_AMGX_Full_CS = np.array([3.1688130379,2.4354128055,3.4661210478])
Petsc_AMGX_Full_DegF = (DOF)/Petsc_AMGX_Full_CS/Petsc_AMGX_Full_Cores
Petsc_AMGX_Full_Eff = Petsc_AMGX_Full_CS[0]/(Petsc_AMGX_Full_CS*Petsc_AMGX_Full_Cores)

d = {"Cores": Petsc_AMGX_Full_Cores,"Iterations": Petsc_AMGX_Full_Iterations,"Residual": Petsc_AMGX_Full_Residual,
    "Error": Petsc_AMGX_Full_Error,"Domain Initialization": Petsc_AMGX_Full_Domain,"Matrix Formation": Petsc_AMGX_Full_Matrix,
    "AMGX Setup": Petsc_AMGX_Full_AMGX,"Linear System Setup": Petsc_AMGX_Full_LSS,"Linear Solve": Petsc_AMGX_Full_LinS,
    "Complete Solve": Petsc_AMGX_Full_CS,"Efficiency": Petsc_AMGX_Full_Eff,"Degrees of Freedom Per Time Per Core": Petsc_AMGX_Full_DegF}
df2 =  pd.DataFrame(data = d)
df2 = df2[["Cores","Iterations","Residual","Error","Domain Initialization","Matrix Formation","AMGX Setup",
         "Linear System Setup","Linear Solve","Complete Solve","Efficiency","Degrees of Freedom Per Time Per Core"]]
nform = {"Error" : "{:6.2e}".format, "Residual" : "{:6.2e}".format}

df2.style.set_caption("Degrees of freedom {:,}".format(DOF)).background_gradient(cmap=cm).format(nform)
# display(HTML(df1.to_html(index=False)))
# Out:
# <style  type="text/css" >
#     #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col4 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col5 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col6 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col7 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col8 {
#             background-color:  #42a442;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col9 {
#             background-color:  #42a442;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col10 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col11 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col0 {
#             background-color:  #99d599;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col1 {
#             background-color:  #e1fde1;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col4 {
#             background-color:  #96d396;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col5 {
#             background-color:  #97d497;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col6 {
#             background-color:  #69ba69;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col7 {
#             background-color:  #74c074;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col8 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col9 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col10 {
#             background-color:  #67b967;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col11 {
#             background-color:  #67b967;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col0 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col1 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col2 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col3 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col7 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col8 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col9 {
#             background-color:  #008000;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col10 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col11 {
#             background-color:  #e5ffe5;
#         }</style>
# <table id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823" ><caption>Degrees of freedom 8,519,680</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Cores</th>
#         <th class="col_heading level0 col1" >Iterations</th>
#         <th class="col_heading level0 col2" >Residual</th>
#         <th class="col_heading level0 col3" >Error</th>
#         <th class="col_heading level0 col4" >Domain Initialization</th>
#         <th class="col_heading level0 col5" >Matrix Formation</th>
#         <th class="col_heading level0 col6" >AMGX Setup</th>
#         <th class="col_heading level0 col7" >Linear System Setup</th>
#         <th class="col_heading level0 col8" >Linear Solve</th>
#         <th class="col_heading level0 col9" >Complete Solve</th>
#         <th class="col_heading level0 col10" >Efficiency</th>
#         <th class="col_heading level0 col11" >Degrees of Freedom Per Time Per Core</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col0" class="data row0 col0" >4</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col1" class="data row0 col1" >53</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col2" class="data row0 col2" >2.69e-11</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col3" class="data row0 col3" >2.30e-04</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col4" class="data row0 col4" >0.638405</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col5" class="data row0 col5" >1.05012</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col6" class="data row0 col6" >5.86014</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col7" class="data row0 col7" >6.91029</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col8" class="data row0 col8" >3.16879</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col9" class="data row0 col9" >3.16881</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col10" class="data row0 col10" >0.25</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row0_col11" class="data row0 col11" >672151</td>
#     </tr>    <tr>
#         <th id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col0" class="data row1 col0" >8</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col1" class="data row1 col1" >54</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col2" class="data row1 col2" >2.54e-11</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col3" class="data row1 col3" >2.30e-04</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col4" class="data row1 col4" >0.325095</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col5" class="data row1 col5" >0.526409</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col6" class="data row1 col6" >4.70225</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col7" class="data row1 col7" >5.22869</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col8" class="data row1 col8" >2.43539</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col9" class="data row1 col9" >2.43541</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col10" class="data row1 col10" >0.162643</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row1_col11" class="data row1 col11" >437281</td>
#     </tr>    <tr>
#         <th id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col0" class="data row2 col0" >16</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col1" class="data row2 col1" >100</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col2" class="data row2 col2" >4.50e+34</td>
#         <td id="T_d0c5b0bd_2312_11e8_b8df_000c29b65823row2_col3" class="data row2 col3" >2.52e+32</td>

# %%
DOF = 8519680
Petsc_AMGX_Full_Cores = np.array([4,8,16])
Petsc_AMGX_Full_Iterations = np.array([53,54,100])
Petsc_AMGX_Full_Residual = np.array([2.6928778673549e-11,2.5390739248273e-11,4.4980646373830e+34])
Petsc_AMGX_Full_Error = np.array([2.3017137276764e-04,2.3017137259899e-04,2.5162658115142e+32])
Petsc_AMGX_Full_Domain = np.array([0.6384049258,0.3250950618,0.1596760514])
Petsc_AMGX_Full_Matrix = np.array([1.0501234819,0.5264085192,0.25415168])
Petsc_AMGX_Full_AMGX = np.array([5.8601402815,4.7022465706,3.3320006146])
Petsc_AMGX_Full_LSS = np.array([6.9102868591,5.2286880751,3.5861939082])
Petsc_AMGX_Full_LinS = np.array([3.168793774,2.4353946755,3.4660941007])
Petsc_AMGX_Full_CS = np.array([3.1688130379,2.4354128055,3.4661210478])
Petsc_AMGX_Full_DegF = (DOF)/Petsc_AMGX_Full_CS/Petsc_AMGX_Full_Cores
Petsc_AMGX_Full_Eff = Petsc_AMGX_Full_CS[0]/(Petsc_AMGX_Full_CS*Petsc_AMGX_Full_Cores)

Initialization = Petsc_AMGX_Full_Domain + Petsc_AMGX_Full_Matrix + Petsc_AMGX_Full_AMGX + Petsc_AMGX_Full_LSS

d = {"Cores": Petsc_AMGX_Full_Cores,"Iterations": Petsc_AMGX_Full_Iterations,"Residual": Petsc_AMGX_Full_Residual,
    "Error": Petsc_AMGX_Full_Error,"Initialization": Initialization,"Linear Solve": Petsc_AMGX_Full_LinS,
    "Complete Solve": Petsc_AMGX_Full_CS,"Efficiency": Petsc_AMGX_Full_Eff,"Degrees of Freedom Per Time Per Core": Petsc_AMGX_Full_DegF}
df2 =  pd.DataFrame(data = d)


df2 = df2[["Cores","Iterations","Initialization","Complete Solve","Residual","Error","Efficiency"]]
nform = {"Error" : "{:6.2e}".format, "Residual" : "{:6.2e}".format}

display(HTML(df2.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Cores</th>
#       <th>Iterations</th>
#       <th>Initialization</th>
#       <th>Complete Solve</th>
#       <th>Residual</th>
#       <th>Error</th>
#       <th>Efficiency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4</td>
#       <td>53</td>
#       <td>14.458956</td>
#       <td>3.168813</td>
#       <td>2.692878e-11</td>
#       <td>2.301714e-04</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>54</td>
#       <td>10.782438</td>
#       <td>2.435413</td>
#       <td>2.539074e-11</td>
#       <td>2.301714e-04</td>
#       <td>0.162643</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>100</td>
#       <td>7.332022</td>
#       <td>3.466121</td>
#       <td>4.498065e+34</td>
#       <td>2.516266e+32</td>
#       <td>0.057139</td>
#     </tr>
#   </tbody>
# </table>

# %%
x = Petsc_AMGX_Full_Cores
y = Petsc_AMGX_Full_CS


plt.plot(x,y,"bo-",label="AMGX (Full matrix)")
plt.yscale("log")
plt.xscale("log")
plt.ylabel("Complete Solve Time (s)")
plt.xlabel("Number of Cores")
plt.title("Full Matrix with 4 level mesh using AMGX")

c = np.polyfit(np.log(x),np.log(y),1)
#  c = np.polyfit(np.log(x[:-2]),np.log(y[-2]),1)
#  Take out points for slope

s = "Best-fit (slope = {:6.2f})".format(c[0])
plt.loglog(x,np.exp(np.polyval(c,np.log(x))),'k--',label=s)

ct = np.array([-1,c[1]])
plt.loglog(x,np.exp(np.polyval(ct,np.log(x))),'.-',label="Theoretical",color='k',markersize=10)


plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(Petsc_AMGX_Full_Cores,Petsc_AMGX_Full_DegF,"ro-",label="Full")
plt.ylabel("Degrees of Freedom Per Time Per Core")
plt.xlabel("Number of Cores")
plt.title("Full Matrix with 4 level mesh using AMGX")
plt.legend()

# %% [markdown]
# # Schur Matrix with Hypre (3)
# This section is the timing results for solving the schur matrix using Hypre. This matrix has 8,519,680 degrees of freedom.

# %%
DOF = 8519680
Petsc_Hypre_Schur_Cores = np.array([1,2,4,8,16,32,64])
Petsc_Hypre_Schur_Iterations = np.array([17,17,16,16,16,16,16])
Petsc_Hypre_Schur_Residual = np.array([6.1286111926919e-11,6.2134639841536e-11,8.6109659566193e-11,7.5298885813740e-11,
                                      5.3103746292143e-11,6.6940599763223e-11,8.3366098373893e-11])
Petsc_Hypre_Schur_Error = np.array([2.3017137184157e-04,2.3017137158352e-04,2.3017137048573e-04,2.3017137047431e-04,
                                   2.3017137130284e-04,2.3017137168851e-04,2.3017137239884e-04])
Petsc_Hypre_Schur_Domain = np.array([2.3197806585,1.2814900692,0.6509059762,0.3381413722,0.1805943389,0.0881982429,
                                    0.0443178398])
Petsc_Hypre_Schur_Matrix = np.array([4.7018186739,2.4026621332,1.3947369839,0.8362200437,0.5057102746,0.2605099553,
                                    0.1436562632])
Petsc_Hypre_Schur_Petsc = np.array([4.6436607393,2.7133943007,1.5416259761,0.931570187,0.6209502718,0.3556885271,
                                   0.2475464451])
Petsc_Hypre_Schur_LSS = np.array([9.3454893739,5.116069321,2.9363804747,1.767811494,1.1267286854,0.6162593805,
                                 0.391279977])
Petsc_Hypre_Schur_LinS = np.array([26.6610254107,14.2418270011,8.8950367894,7.5887215761,7.1686851578,5.1473824642,
                                  1.0967835393])
Petsc_Hypre_Schur_PatS = np.array([0.2467111158,0.1406464368,0.0988530172,0.0821939839,0.0843995927,0.0470875859,
                                  0.0091415173])
Petsc_Hypre_Schur_CS = np.array([26.9077451058,14.3824872351,8.9939953395,7.6712551782,7.2538566353,5.2004614297,
                                1.1060020951])
Petsc_Hypre_Schur_DegF = (DOF)/Petsc_Hypre_Schur_CS/Petsc_Hypre_Schur_Cores
Petsc_Hypre_Schur_Eff = Petsc_Hypre_Schur_CS[0]/(Petsc_Hypre_Schur_CS*Petsc_Hypre_Schur_Cores)

d = {"Cores": Petsc_Hypre_Schur_Cores,"Iterations": Petsc_Hypre_Schur_Iterations,"Residual": Petsc_Hypre_Schur_Residual,
    "Error": Petsc_Hypre_Schur_Error,"Domain Initialization": Petsc_Hypre_Schur_Domain,"Matrix Formation": Petsc_Hypre_Schur_Matrix,
    "Hypre Setup": Petsc_Hypre_Schur_Petsc,"Linear System Setup": Petsc_Hypre_Schur_LSS,"Linear Solve": Petsc_Hypre_Schur_LinS,
    "Patch Solve": Petsc_Hypre_Schur_PatS,"Complete Solve": Petsc_Hypre_Schur_CS,"Efficiency": Petsc_Hypre_Schur_Eff,
     "Degrees of Freedom Per Time Per Core": Petsc_Hypre_Schur_DegF}
df3 =  pd.DataFrame(data = d)
df3 = df3[["Cores","Iterations","Residual","Error","Domain Initialization","Matrix Formation","Hypre Setup",
         "Linear System Setup","Linear Solve","Patch Solve","Complete Solve","Efficiency","Degrees of Freedom Per Time Per Core"]]
nform = {"Error" : "{:6.2e}".format, "Residual" : "{:6.2e}".format}

df3.style.set_caption("Degrees of freedom {:,}".format(DOF)).background_gradient(cmap=cm).format(nform)
# display(HTML(df1.to_html(index=False)))
# Out:
# <style  type="text/css" >
#     #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col1 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col2 {
#             background-color:  #ade0ad;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col3 {
#             background-color:  #43a543;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col4 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col5 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col6 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col7 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col8 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col9 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col10 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col11 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row0_col12 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col0 {
#             background-color:  #e2fde2;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col1 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col2 {
#             background-color:  #a6dca6;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col3 {
#             background-color:  #61b661;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col4 {
#             background-color:  #68ba68;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col5 {
#             background-color:  #74c074;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col6 {
#             background-color:  #65b865;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col7 {
#             background-color:  #6cbc6c;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col8 {
#             background-color:  #70be70;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col9 {
#             background-color:  #67b967;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col10 {
#             background-color:  #70be70;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col11 {
#             background-color:  #118911;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row1_col12 {
#             background-color:  #118911;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col0 {
#             background-color:  #dbf9db;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col2 {
#             background-color:  #008000;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col4 {
#             background-color:  #a8dda8;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col5 {
#             background-color:  #a6dca6;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col6 {
#             background-color:  #a2daa2;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col7 {
#             background-color:  #a5dba5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col8 {
#             background-color:  #9fd89f;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col9 {
#             background-color:  #8fcf8f;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col10 {
#             background-color:  #9fd89f;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col11 {
#             background-color:  #44a644;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row2_col12 {
#             background-color:  #44a644;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col0 {
#             background-color:  #ccf1cc;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col2 {
#             background-color:  #4ba94b;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col4 {
#             background-color:  #c8efc8;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col5 {
#             background-color:  #c3ecc3;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col6 {
#             background-color:  #c2ecc2;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col7 {
#             background-color:  #c2ecc2;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col8 {
#             background-color:  #abdfab;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col9 {
#             background-color:  #9fd89f;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col10 {
#             background-color:  #abdfab;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col11 {
#             background-color:  #9ad59a;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row3_col12 {
#             background-color:  #9ad59a;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col0 {
#             background-color:  #b0e1b0;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col3 {
#             background-color:  #82c882;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col4 {
#             background-color:  #d8f8d8;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col5 {
#             background-color:  #d3f5d3;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col6 {
#             background-color:  #d3f5d3;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col7 {
#             background-color:  #d3f5d3;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col8 {
#             background-color:  #b0e1b0;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col9 {
#             background-color:  #9dd79d;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col10 {
#             background-color:  #b0e1b0;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col11 {
#             background-color:  #d3f5d3;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row4_col12 {
#             background-color:  #d3f5d3;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col0 {
#             background-color:  #75c175;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col2 {
#             background-color:  #85ca85;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col3 {
#             background-color:  #55af55;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col4 {
#             background-color:  #e2fde2;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col5 {
#             background-color:  #e0fce0;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col6 {
#             background-color:  #e0fce0;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col7 {
#             background-color:  #e0fce0;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col8 {
#             background-color:  #c2ebc2;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col9 {
#             background-color:  #c2ebc2;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col10 {
#             background-color:  #c2ebc2;
#         }    #T_d0c5b0be_2312_11e8_b8df_000c29b65823row5_col11

# %%
DOF = 8519680
Petsc_Hypre_Schur_Cores = np.array([1,2,4,8,16,32,64])
Petsc_Hypre_Schur_Iterations = np.array([17,17,16,16,16,16,16])
Petsc_Hypre_Schur_Residual = np.array([6.1286111926919e-11,6.2134639841536e-11,8.6109659566193e-11,7.5298885813740e-11,
                                      5.3103746292143e-11,6.6940599763223e-11,8.3366098373893e-11])
Petsc_Hypre_Schur_Error = np.array([2.3017137184157e-04,2.3017137158352e-04,2.3017137048573e-04,2.3017137047431e-04,
                                   2.3017137130284e-04,2.3017137168851e-04,2.3017137239884e-04])
Petsc_Hypre_Schur_Domain = np.array([2.3197806585,1.2814900692,0.6509059762,0.3381413722,0.1805943389,0.0881982429,
                                    0.0443178398])
Petsc_Hypre_Schur_Matrix = np.array([4.7018186739,2.4026621332,1.3947369839,0.8362200437,0.5057102746,0.2605099553,
                                    0.1436562632])
Petsc_Hypre_Schur_Petsc = np.array([4.6436607393,2.7133943007,1.5416259761,0.931570187,0.6209502718,0.3556885271,
                                   0.2475464451])
Petsc_Hypre_Schur_LSS = np.array([9.3454893739,5.116069321,2.9363804747,1.767811494,1.1267286854,0.6162593805,
                                 0.391279977])
Petsc_Hypre_Schur_LinS = np.array([26.6610254107,14.2418270011,8.8950367894,7.5887215761,7.1686851578,5.1473824642,
                                  1.0967835393])
Petsc_Hypre_Schur_PatS = np.array([0.2467111158,0.1406464368,0.0988530172,0.0821939839,0.0843995927,0.0470875859,
                                  0.0091415173])
Petsc_Hypre_Schur_CS = np.array([26.9077451058,14.3824872351,8.9939953395,7.6712551782,7.2538566353,5.2004614297,
                                1.1060020951])
Initialization = Petsc_Hypre_Full_Domain + Petsc_Hypre_Full_Matrix + Petsc_Hypre_Full_Petsc + Petsc_Hypre_Full_LSS
Petsc_Hypre_Schur_Eff = Petsc_Hypre_Schur_CS[0]/(Petsc_Hypre_Schur_CS*Petsc_Hypre_Schur_Cores)

d = {"Cores": Petsc_Hypre_Schur_Cores,"Iterations": Petsc_Hypre_Schur_Iterations,"Residual": Petsc_Hypre_Schur_Residual,
    "Error": Petsc_Hypre_Schur_Error,"Initialization": Initialization,"Linear Solve": Petsc_Hypre_Schur_LinS,
    "Patch Solve": Petsc_Hypre_Schur_PatS,"Complete Solve": Petsc_Hypre_Schur_CS,"Efficiency": Petsc_Hypre_Schur_Eff}

df3 =  pd.DataFrame(data = d)
df3 = df3[["Cores","Iterations","Initialization","Complete Solve","Residual","Error","Efficiency"]]
nform = {"Error" : "{:6.2e}".format, "Residual" : "{:6.2e}".format}

display(HTML(df3.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Cores</th>
#       <th>Iterations</th>
#       <th>Initialization</th>
#       <th>Complete Solve</th>
#       <th>Residual</th>
#       <th>Error</th>
#       <th>Efficiency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>17</td>
#       <td>29.785229</td>
#       <td>26.907745</td>
#       <td>6.128611e-11</td>
#       <td>0.00023</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>17</td>
#       <td>788.721963</td>
#       <td>14.382487</td>
#       <td>6.213464e-11</td>
#       <td>0.00023</td>
#       <td>0.935434</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>16</td>
#       <td>375.625881</td>
#       <td>8.993995</td>
#       <td>8.610966e-11</td>
#       <td>0.00023</td>
#       <td>0.747936</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>16</td>
#       <td>145.526098</td>
#       <td>7.671255</td>
#       <td>7.529889e-11</td>
#       <td>0.00023</td>
#       <td>0.438451</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>16</td>
#       <td>44.861707</td>
#       <td>7.253857</td>
#       <td>5.310375e-11</td>
#       <td>0.00023</td>
#       <td>0.231840</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>16</td>
#       <td>13.494609</td>
#       <td>5.200461</td>
#       <td>6.694060e-11</td>
#       <td>0.00023</td>
#       <td>0.161691</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>16</td>
#       <td>5.885433</td>
#       <td>1.106002</td>
#       <td>8.336610e-11</td>
#       <td>0.00023</td>
#       <td>0.380138</td>
#     </tr>
#   </tbody>
# </table>

# %%
x = Petsc_Hypre_Schur_Cores
y = Petsc_Hypre_Schur_CS


plt.plot(x,y,"bo-",label="Hypre (Schur matrix)")
plt.yscale("log")
plt.xscale("log")
plt.ylabel("Complete Solve Time (s)")
plt.xlabel("Number of Cores")
plt.title("Schur Matrix with 4 level mesh using Hypre")

c = np.polyfit(np.log(x),np.log(y),1)
#  c = np.polyfit(np.log(x[:-2]),np.log(y[-2]),1)
#  Take out points for slope

s = "Best-fit (slope = {:6.2f})".format(c[0])
plt.loglog(x,np.exp(np.polyval(c,np.log(x))),'k--',label=s)

ct = np.array([-1,c[1]])
plt.loglog(x,np.exp(np.polyval(ct,np.log(x))),'.-',label="Theoretical",color='k',markersize=10)


plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(Petsc_Hypre_Schur_Cores,Petsc_Hypre_Schur_DegF,"ro-",label="Full")
plt.ylabel("Degrees of Freedom Per Time Per Core")
plt.xlabel("Number of Cores")
plt.title("Schur Matrix with 4 level mesh using Hypre")
plt.legend()

# %% [markdown]
# # Schur Matrix with AMGX (4)
#
# This section is the timing results for solving the schur matrix using AMGX. This matrix has 8,519,680 degrees of freedom.

# %%
DOF = 8519680
Petsc_AMGX_Schur_Cores = np.array([1,2,4,8,16])
Petsc_AMGX_Schur_Iterations = np.array([19,20,20,41,43])
Petsc_AMGX_Schur_Residual = np.array([5.2936983910698e-11,7.5600542815270e-11,7.4026913091532e-11,7.6694115873228e-11,
                                     7.7819407916075e-11])
Petsc_AMGX_Schur_Error = np.array([2.3017137248232e-04,2.3017137207938e-04,2.3017137136600e-04,2.3017140291427e-04,
                                  2.3017137841256e-04])
Petsc_AMGX_Schur_Domain = np.array([2.3337616937,1.2930742003,0.6458368543,0.320829864,0.1596537432])
Petsc_AMGX_Schur_Matrix = np.array([4.7120087786,2.4247896112,1.3989577046,0.7023233447,0.3609061177])
Petsc_AMGX_Schur_AMGX = np.array([3.3300434468,2.3564731745,3.2339107711,1.1047223745,0.8511620792])
Petsc_AMGX_Schur_LSS = np.array([8.0420624677,4.7812800098,4.6328985485,1.807076874,1.2121099722])
Petsc_AMGX_Schur_LinS = np.array([1.4526519399,0.8794994916,0.5656855198,0.791941556,0.6672197783])
Petsc_AMGX_Schur_PS = np.array([0.2378894442,0.1342686384,0.0674168489,0.0339031809,0.0184403416])
Petsc_AMGX_Schur_CS = np.array([1.6905478806,1.013778522,0.6331196053,0.8258673021,0.6856942482])
Petsc_AMGX_Schur_DegF = (DOF)/Petsc_AMGX_Schur_CS/Petsc_AMGX_Schur_Cores
Petsc_AMGX_Schur_Eff = np.array(np.ones(len(Petsc_AMGX_Schur_Cores))*Petsc_AMGX_Schur_CS[0]/(Petsc_AMGX_Schur_CS*Petsc_AMGX_Schur_Cores))

d = {"Cores": Petsc_AMGX_Schur_Cores,"Iterations": Petsc_AMGX_Schur_Iterations,"Residual": Petsc_AMGX_Schur_Residual,
    "Error": Petsc_AMGX_Schur_Error,"Domain Initialization": Petsc_AMGX_Schur_Domain,"Matrix Formation": Petsc_AMGX_Schur_Matrix,
    "AMGX Setup": Petsc_AMGX_Schur_AMGX,"Linear System Setup": Petsc_AMGX_Schur_LSS,"Linear Solve": Petsc_AMGX_Schur_LinS,
    "Patch Solve": Petsc_AMGX_Schur_PS,"Complete Solve": Petsc_AMGX_Schur_CS,"Efficiency": Petsc_AMGX_Schur_Eff,
    "Degrees of Freedom Per Time Per Core": Petsc_AMGX_Schur_DegF}
df4 =  pd.DataFrame(data = d)
df4 = df4[["Cores","Iterations","Residual","Error","Domain Initialization","Matrix Formation","AMGX Setup",
         "Linear System Setup","Linear Solve","Patch Solve","Complete Solve","Efficiency","Degrees of Freedom Per Time Per Core"]]
nform = {"Error" : "{:6.2e}".format, "Residual" : "{:6.2e}".format}

df4.style.set_caption("Degrees of freedom {:,}".format(DOF)).background_gradient(cmap=cm).format(nform)
# display(HTML(df1.to_html(index=False)))
# Out:
# <style  type="text/css" >
#     #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col3 {
#             background-color:  #ddfbdd;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col4 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col5 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col6 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col7 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col8 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col9 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col10 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col11 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row0_col12 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col0 {
#             background-color:  #d6f7d6;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col1 {
#             background-color:  #dcfadc;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col2 {
#             background-color:  #148b14;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col3 {
#             background-color:  #e1fde1;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col4 {
#             background-color:  #6ebd6e;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col5 {
#             background-color:  #79c379;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col6 {
#             background-color:  #5ab25a;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col7 {
#             background-color:  #6ebd6e;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col8 {
#             background-color:  #94d294;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col9 {
#             background-color:  #6cbc6c;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col10 {
#             background-color:  #93d193;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col11 {
#             background-color:  #2d992d;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row1_col12 {
#             background-color:  #2d992d;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col0 {
#             background-color:  #b8e6b8;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col1 {
#             background-color:  #dcfadc;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col2 {
#             background-color:  #239323;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col4 {
#             background-color:  #b2e3b2;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col5 {
#             background-color:  #afe1af;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col6 {
#             background-color:  #088408;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col7 {
#             background-color:  #72bf72;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col8 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col9 {
#             background-color:  #b2e3b2;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col10 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col11 {
#             background-color:  #5ab25a;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row2_col12 {
#             background-color:  #5ab25a;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col0 {
#             background-color:  #7ac47a;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col1 {
#             background-color:  #138a13;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col2 {
#             background-color:  #0a850a;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col3 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col4 {
#             background-color:  #d5f6d5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col5 {
#             background-color:  #d3f5d3;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col6 {
#             background-color:  #cef2ce;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col7 {
#             background-color:  #d2f4d2;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col8 {
#             background-color:  #abdfab;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col9 {
#             background-color:  #d5f6d5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col10 {
#             background-color:  #bce8bc;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col11 {
#             background-color:  #caf0ca;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row3_col12 {
#             background-color:  #caf0ca;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col0 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col1 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col2 {
#             background-color:  #008000;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col3 {
#             background-color:  #b2e3b2;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col7 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col8 {
#             background-color:  #cbf1cb;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col9 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col10 {
#             background-color:  #dbf9db;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col11 {
#             background-color:  #e5ffe5;
#         }    #T_d2304d36_2312_11e8_b8df_000c29b65823row4_col12 {
#             background-color:  #e5ffe5;
#         }</style>
# <table id="T_d2304d36_2312_11e8_b8df_000c29b65823" ><caption>Degrees of freedom 8,519,680</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Cores</th>
#         <th class="col_heading level0 col1" >Iterations</th>
#         <th class="col_heading level0 col2" >Residual</th>
#         <th class="col_heading level0 col3" >Error</th>
#         <th class="col_heading level0 col4" >Domain Initialization</th>
#         <th class="col_heading level0 col5" >Matrix Formation</th>
#         <th class="col_heading level0 col6" >AMGX Setup</th>
#         <th class="col_heading level0 col7" >Linear System Setup</th>
#         <th class="col_heading level0 col8" >Linear Solve</th>
#         <th class="col_heading level0 col9" >Patch Solve</th>
#         <th class="col_heading level0 col10" >Complete Solve</th>
#         <th class="col_heading level0 col11" >Efficiency</th>
#         <th class="col_heading level0 col12" >Degrees of Freedom Per Time Per Core</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d2304d36_2312_11e8_b8df_000c29b65823level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_d2304d36_23

# %%
DOF = 8519680
Petsc_AMGX_Schur_Cores = np.array([1,2,4,8,16])
Petsc_AMGX_Schur_Iterations = np.array([19,20,20,41,43])
Petsc_AMGX_Schur_Residual = np.array([5.2936983910698e-11,7.5600542815270e-11,7.4026913091532e-11,7.6694115873228e-11,
                                     7.7819407916075e-11])
Petsc_AMGX_Schur_Error = np.array([2.3017137248232e-04,2.3017137207938e-04,2.3017137136600e-04,2.3017140291427e-04,
                                  2.3017137841256e-04])
Petsc_AMGX_Schur_Domain = np.array([2.3337616937,1.2930742003,0.6458368543,0.320829864,0.1596537432])
Petsc_AMGX_Schur_Matrix = np.array([4.7120087786,2.4247896112,1.3989577046,0.7023233447,0.3609061177])
Petsc_AMGX_Schur_AMGX = np.array([3.3300434468,2.3564731745,3.2339107711,1.1047223745,0.8511620792])
Petsc_AMGX_Schur_LSS = np.array([8.0420624677,4.7812800098,4.6328985485,1.807076874,1.2121099722])
Petsc_AMGX_Schur_LinS = np.array([1.4526519399,0.8794994916,0.5656855198,0.791941556,0.6672197783])
Petsc_AMGX_Schur_PS = np.array([0.2378894442,0.1342686384,0.0674168489,0.0339031809,0.0184403416])
Petsc_AMGX_Schur_CS = np.array([1.6905478806,1.013778522,0.6331196053,0.8258673021,0.6856942482])
Petsc_AMGX_Schur_DegF = (DOF)/Petsc_AMGX_Schur_CS/Petsc_AMGX_Schur_Cores
Petsc_AMGX_Schur_Eff = np.array(np.ones(len(Petsc_AMGX_Schur_Cores))*Petsc_AMGX_Schur_CS[0]/(Petsc_AMGX_Schur_CS*Petsc_AMGX_Schur_Cores))

Initialization = Petsc_AMGX_Schur_Domain + Petsc_AMGX_Schur_Matrix + Petsc_AMGX_Schur_AMGX + Petsc_AMGX_Schur_LSS

d = {"Cores": Petsc_AMGX_Schur_Cores,"Iterations": Petsc_AMGX_Schur_Iterations,"Residual": Petsc_AMGX_Schur_Residual,
    "Error": Petsc_AMGX_Schur_Error,"Initialization": Initialization,"Linear Solve": Petsc_AMGX_Schur_LinS,
    "Complete Solve": Petsc_AMGX_Schur_CS,"Efficiency": Petsc_AMGX_Schur_Eff,"Degrees of Freedom Per Time Per Core": Petsc_AMGX_Schur_DegF}
df4 =  pd.DataFrame(data = d)


df4 = df4[["Cores","Iterations","Initialization","Complete Solve","Residual","Error","Efficiency"]]
nform = {"Error" : "{:6.2e}".format, "Residual" : "{:6.2e}".format}

display(HTML(df4.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Cores</th>
#       <th>Iterations</th>
#       <th>Initialization</th>
#       <th>Complete Solve</th>
#       <th>Residual</th>
#       <th>Error</th>
#       <th>Efficiency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>19</td>
#       <td>18.417876</td>
#       <td>1.690548</td>
#       <td>5.293698e-11</td>
#       <td>0.00023</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>20</td>
#       <td>10.855617</td>
#       <td>1.013779</td>
#       <td>7.560054e-11</td>
#       <td>0.00023</td>
#       <td>0.833786</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>20</td>
#       <td>9.911604</td>
#       <td>0.633120</td>
#       <td>7.402691e-11</td>
#       <td>0.00023</td>
#       <td>0.667547</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>41</td>
#       <td>3.934952</td>
#       <td>0.825867</td>
#       <td>7.669412e-11</td>
#       <td>0.00023</td>
#       <td>0.255875</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>43</td>
#       <td>2.583832</td>
#       <td>0.685694</td>
#       <td>7.781941e-11</td>
#       <td>0.00023</td>
#       <td>0.154091</td>
#     </tr>
#   </tbody>
# </table>

# %%
x = Petsc_AMGX_Schur_Cores
y = Petsc_AMGX_Schur_CS


plt.plot(x,y,"bo-",label="AMGX (Schur matrix)")
plt.yscale("log")
plt.xscale("log")
plt.ylabel("Complete Solve Time (s)")
plt.xlabel("Number of Cores")
plt.title("Schur Matrix with 4 level mesh using AMGX")

c = np.polyfit(np.log(x),np.log(y),1)
#  c = np.polyfit(np.log(x[:-2]),np.log(y[-2]),1)
#  Take out points for slope

s = "Best-fit (slope = {:6.2f})".format(c[0])
plt.loglog(x,np.exp(np.polyval(c,np.log(x))),'k--',label=s)

ct = np.array([-1,c[1]])
plt.loglog(x,np.exp(np.polyval(ct,np.log(x))),'.-',label="Theoretical",color='k',markersize=10)


plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(Petsc_AMGX_Schur_Cores,Petsc_AMGX_Schur_DegF,"ro-",label="Full")
plt.ylabel("Degrees of Freedom Per Time Per Core")
plt.xlabel("Number of Cores")
plt.title("Schur Matrix with 4 level mesh using AMGX")
plt.legend()

# %% [markdown]
# # Comparison of Full vs Schur solve
#
# First comparison is for Hypre, second for AMGX.

# %%
xf = Petsc_Hypre_Full_Cores
yf = Petsc_Hypre_Full_CS
xs = Petsc_Hypre_Schur_Cores
ys = Petsc_Hypre_Schur_CS


plt.plot(xf,yf,"ro-",label="Hypre (Full matrix)")
plt.plot(xs,ys,"bo-",label="Hypre (Schur matrix)")
plt.yscale("log")
plt.xscale("log")
plt.ylabel("Complete Solve Time (s)")
plt.xlabel("Number of Cores")
plt.title("Schur vs Full Matrix with 4 level mesh using Hypre")

cf = np.polyfit(np.log(xf),np.log(yf),1)
cs = np.polyfit(np.log(xs),np.log(ys),1)
#  c = np.polyfit(np.log(x[:-2]),np.log(y[-2]),1)
#  Take out points for slope

sf = "Best-fit (slope = {:6.2f})".format(cf[0])
ss = "Best-fit (slope = {:6.2f})".format(cs[0])
plt.loglog(xf,np.exp(np.polyval(cf,np.log(xf))),'k--',label=sf)
plt.loglog(xs,np.exp(np.polyval(cs,np.log(xs))),'k--',label=ss)


plt.legend()
plt.show
plt.ylim(ymin=6e-1,ymax=1e2)
# Out:
# (0.6, 100.0)

# %%
xf = Petsc_AMGX_Full_Cores
yf = Petsc_AMGX_Full_CS
xs = Petsc_AMGX_Schur_Cores
ys = Petsc_AMGX_Schur_CS


plt.plot(xf,yf,"ro-",label="AMGX (Full matrix)")
plt.plot(xs,ys,"bo-",label="AMGX (Schur matrix)")
plt.yscale("log")
plt.xscale("log")
plt.ylabel("Complete Solve Time (s)")
plt.xlabel("Number of Cores")
plt.title("Schur vs Full Matrix with 4 level mesh using AMGX")

cf = np.polyfit(np.log(xf),np.log(yf),1)
cs = np.polyfit(np.log(xs),np.log(ys),1)
#  c = np.polyfit(np.log(x[:-2]),np.log(y[-2]),1)
#  Take out points for slope

sf = "Best-fit (slope = {:6.2f})".format(cf[0])
ss = "Best-fit (slope = {:6.2f})".format(cs[0])
plt.loglog(xf,np.exp(np.polyval(cf,np.log(xf))),'k--',label=sf)
plt.loglog(xs,np.exp(np.polyval(cs,np.log(xs))),'k--',label=ss)


plt.legend()
plt.show
plt.ylim(ymin=6e-1,ymax=1e2)
# Out:
# (0.6, 100.0)
