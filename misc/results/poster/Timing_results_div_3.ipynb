# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <hr style="border-width:3px; border-color:coral"/>
# # Timing results for pressure Poisson solver
# <hr style="border-width:3px; border-color:coral"/>
#
#
# Four sets of solver types are reported. In the full matrix system, the discretized system $A\mathbf x = \mathbf b$ is solved. In the Schur complement system, a linear system for the interface values is solved, and a fast FFT-based solver is used for patch solves.  In either the Full or the Schur approaches, GMRES is used as the basci solver (from HYPRE?) along with an an AMG pre-conditioner, either from HYPRE (BoomerAMG) or using the GPU based implementation AMGX.
#
# The four simulations reported below are then
# * Full matrix with HYPRE used as the pre-conditioner for the full system. [Full matrix (HYPRE)](#fullhypre)
# * Schur matrix with HYPRE used as the pre-conditioner for the Schur complement system. [Schur matrix (HYPRE)](#schurhypre)
# * Full matrix with AMGX used as the pre-conditioner for the full system. [Full matrix (AMGX)](#fullamgx)
# * Schur matrix with AMGX used as the pre-conditioner for the Schur complement system. [Schur matrix (AMGX)](#schuramgx)
#
# We also include comparisions between HYPRE and the Schur matrix approach [here](#comparisons).
#
# <hr style="border-width:3px; border-color:coral"/>

# %%
# %reload_ext autoreload
# %autoreload 2

from results_output import *

# %% [markdown]
# ## Read in spreadsheet data

# %%
timing_results = pd.read_excel("Timing_results.xlsx",sheet_name=None)
div_factor = 3
df_full_hypre  = timing_results["full_hypre ({:d})".format(div_factor)]
df_schur_hypre = timing_results["schur_hypre ({:d})".format(div_factor)]
df_full_amgx   = timing_results["full_amgx ({:d})".format(div_factor)]
df_full_amgx.index = [2,3,4]
df_schur_amgx  = timing_results["schur_amgx ({:d})".format(div_factor)]


# For HYPRE results
cols_setup_hypre = ['matrix_setup','hypre_setup']
df_full_hypre['complete_setup'] = df_full_hypre[cols_setup_hypre].sum(axis=1)
df_schur_hypre['complete_setup'] = df_schur_hypre[cols_setup_hypre].sum(axis=1)

# Fix AMGX results
cols_setup_amgx = ['matrix_setup','amgx_setup']
df_full_amgx['complete_setup'] = df_full_amgx[cols_setup_amgx].sum(axis=1)
df_schur_amgx['complete_setup'] = df_schur_amgx[cols_setup_amgx].sum(axis=1)

cols_solve_full =['linsolve']
cols_solve_schur = ['linsolve','patch_solve']

# %% [markdown]
# <a id='fullhypre'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Full matrix (HYPRE)
# <hr style="border-width:3px; border-color:coral"/>

# %%
print_table(df_full_hypre);
# Out:
# <style  type="text/css" >
#     #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col4 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col5 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col6 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col7 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col8 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col9 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow0_col10 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col4 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col5 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col6 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col7 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col8 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col9 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow1_col10 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col4 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col5 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col6 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col7 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col8 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col9 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow2_col10 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col4 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col5 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col6 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col7 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col8 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col9 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow3_col10 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col4 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col5 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col6 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col7 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col8 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col9 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow4_col10 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col4 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col5 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col6 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col7 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col8 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col9 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow5_col10 {
#             width:  100px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow6_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow6_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow6_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_307c_11e8_bd31_784f439ce51drow6_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4149845a_

# %% [markdown]
# ## Full matrix (HYPRE) : Setup

# %%
barh_plot(df_full_hypre,cols_setup_hypre)
plt.title('Full matrix (setup)',fontsize=16);
set_xticks(5,2.5,units='minutes')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Solve

# %%
bar_plot(df_full_hypre,cols_solve_full)
plt.title('Full solve (HYPRE)',fontsize=16);
set_xticks(0.5,0.25,units='minutes')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Strong scaling

# %%
strong_scaling(df_full_hypre,field='complete_solve')
plt.title('Full matrix (HYPRE)');
plt.ylabel('Time (seconds)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Time (seconds)')

# %% [markdown]
# ## Full matrix (HYPRE) : Efficiency

# %%
efficiency(df_full_hypre,'complete_solve')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='schurhypre'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Schur matrix (HYPRE)
# <hr style="border-width:3px; border-color:coral"/>

# %%
print_table(df_schur_hypre);
# Out:
# <style  type="text/css" >
#     #T_693c7580_307c_11e8_a943_784f439ce51drow0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col4 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col5 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col6 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col7 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col8 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col9 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col10 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow0_col11 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col4 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col5 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col6 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col7 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col8 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col9 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col10 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow1_col11 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col4 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col5 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col6 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col7 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col8 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col9 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col10 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow2_col11 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col4 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col5 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col6 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col7 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col8 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col9 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col10 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow3_col11 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col4 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col5 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col6 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col7 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col8 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col9 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col10 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow4_col11 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col4 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col5 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col6 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col7 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col8 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col9 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col10 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow5_col11 {
#             width:  100px;
#         }    #T_693c7580_307c_11e8_a943_784f439ce51drow6_col0 {

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup
#
# Use HYPRE to solve the Schur complement system

# %%
barh_plot(df_schur_hypre,cols_setup_hypre)
plt.title('Schur matrix (HYPRE) : Setup',fontsize=16);
set_xticks(5,2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Strong scaling (setup)

# %%
strong_scaling(df_schur_hypre,field='complete_setup')
plt.title('Schur matrix (HYPRE) : Strong scaling (setup)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup

# %%
efficiency(df_schur_hypre,'complete_setup')

# %% [markdown]
# ## Schur matrix (HYPRE) : Solve

# %%
barh_plot(df_schur_hypre,cols_solve_schur)
plt.title('Schur matrix (HYPRE) : solve',fontsize=16);
set_xticks(5,2.5)

# %% [markdown]
# ## Schur matrix (HYPRE) : Strong scaling (solve)

# %%
strong_scaling(df_schur_hypre,field='complete_solve')
plt.title('Schur matrix (HYPRE) : Strong scaling (solve)');
plt.ylabel('Time (seconds)');

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup vs solve time

# %%
bar_plot(df_schur_hypre,['complete_solve','complete_setup'])
plt.title('Schur matrix (HYPRE) : Setup vs. solve',fontsize=16);
set_xticks(5,2.5)

# %% [markdown]
# ## Schur matrix (HYPRE) : Efficiency

# %%
efficiency(df_schur_hypre,'complete_solve')

# %% [markdown]
# <a id='fullamgx'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Full matrix (AMGX)
# <hr style="border-width:3px; border-color:coral"/>
#
# Use AMGX to solve the full matrix system

# %%
print_table(df_full_amgx);

# %% [markdown]
# ## Full matrix (AMGX) : Setup

# %%
barh_plot(df_full_amgx,cols_setup_amgx)
plt.title('Full matrix (AMGX) : Setup',fontsize=16);
set_xticks(5,2.5)

# %% [markdown]
# ## Full matrix (AMGX) : Solve

# %%
barh_plot(df_full_amgx,cols_solve_full)
plt.title('Full matrix (AMGX) : solve',fontsize=16);
set_xticks(1,0.25)

# %% [markdown]
# ## Full matrix (AMGX) : Setup vs. solve

# %%
bar_plot(df_full_amgx,['complete_solve','complete_setup'])
plt.title('Full matrix (AMGX) : Setup vs. solve',fontsize=16);
set_xticks(5,2.5)

# %% [markdown]
# ## Full matrix (AMGX ) : Efficiency
# This one doesn't work, since we don't have a values for 1 processor (this could easily be fixed, though).

# %%
# efficiency(df_full_amgx,'complete_solve')

# %% [markdown]
# <a id='schuramgx'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Schur matrix (AMGX)
# <hr style="border-width:3px; border-color:coral"/>
#
# Solve the Schur complement system using AMGX

# %%
print_table(df_schur_amgx);

# %% [markdown]
# ## Schur matrix (AMGX) : Setup
#
# Use AMGX to solve the Schur complement system

# %%
barh_plot(df_schur_amgx,cols_setup_amgx)
plt.title('Schur matrix (AMGX) : Setup',fontsize=16);
set_xticks(5,2.5)

# %% [markdown]
# ## Schur matrix (AMGX) : Solve

# %%
barh_plot(df_schur_amgx,cols_solve_schur)
plt.title('Schur matrix (AMGX) : solve',fontsize=16);
set_xticks(0.5,2.5)

# %% [markdown]
# ## Schur matrix (AMGX) : Setup vs. solve

# %%
bar_plot(df_schur_amgx,['complete_solve','complete_setup'])
plt.title('Schur matrix (AMGX) : Setup vs. solve',fontsize=16);
set_xticks(5,2.5)

# %% [markdown]
# ## Schur matrix (AMGX) : Efficiency

# %%
efficiency(df_schur_amgx,'complete_solve')

# %% [markdown]
# <a id='comparisons'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Comparisons between full and Schur systems
# <hr style="border-width:3px; border-color:coral"/>

# %%
panel = pd.Panel({'Full (HYPRE)' : df_full_hypre, 'Schur (HYPRE)' : df_schur_hypre,
                 'Full (AMGX)' : df_full_amgx, 'Schur (AMGX)' : df_schur_amgx})
procs = df_full_hypre['p']

# %% [markdown]
# ## Comparisons : Setup

# %%
df_setup = panel.minor_xs('complete_setup')
df_setup.insert(0,'p',procs)
df_setup

# %%
df_setup.plot(x='p',logx=True,logy=True,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Setup time',fontsize=16);
fix_xticks(df_setup['p'].values)

# %%
cols = ['Schur (AMGX)', 'Full (AMGX)', 'Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_setup,cols=cols)
plt.title("Comparisons : Setup", fontsize=16);
set_xticks(2.5,0.5,units='minutes')

# %%
cols = ['Schur (AMGX)', 'Full (AMGX)', 'Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_setup,cols=cols)
plt.title("Comparisons : Setup", fontsize=16);
set_xticks(35,2.5)

# %% [markdown]
# ## Comparisons : Solve

# %%
df_solve = panel.minor_xs('complete_solve')
df_solve.insert(0,'p',procs)
df_solve
# Out:
#     p  Full (AMGX)  Full (HYPRE)  Schur (AMGX)  Schur (HYPRE)
# 0   1          NaN     68.068060      1.690548      26.907745
# 1   2          NaN     40.492793      1.013779      14.382487
# 2   4     3.168813     29.408292      0.633120       8.993995
# 3   8     2.435413     24.118250      0.825867       7.671255
# 4  16     3.466121     17.558434      0.685694       7.253857
# 5  32          NaN     10.271640           NaN       5.200461
# 6  64          NaN      8.431653           NaN       1.106002

# %%
cols = ['p','Full (HYPRE)','Schur (HYPRE)']
df_solve[cols].plot(x='p',logx=True,logy=False,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Solve time (HYPRE)',fontsize=16);
fix_xticks(df_solve['p'].values)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['p','Full (AMGX)','Schur (AMGX)']
df_solve[cols].plot(x='p',logx=True,logy=False,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Solve time (AMGX)',fontsize=16);
fix_xticks(df_solve['p'].values)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['Schur (AMGX)', 'Full (AMGX)', 'Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_solve,cols=cols)
plt.title("Timing (solve)", fontsize=16);
# Out:
# <img src="data:image/png;base64,..." width="640">
