# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <hr style="border-width:3px; border-color:coral"/>
# # Timing results for pressure Poisson solver
# <hr style="border-width:3px; border-color:coral"/>
#
#
# Four sets of solver types are reported. In the full matrix system, the discretized system $A\mathbf x = \mathbf b$ is solved. In the Schur complement system, a linear system for the interface values is solved, and a fast FFT-based solver is used for patch solves.  In either the Full or the Schur approaches, GMRES is used as the basci solver (from HYPRE?) along with an an AMG pre-conditioner, either from HYPRE (BoomerAMG) or using the GPU based implementation AMGX.
#
# The four simulations reported below are then
# * Full matrix with HYPRE used as the pre-conditioner for the full system. [Full matrix (HYPRE)](#fullhypre)
# * Schur matrix with HYPRE used as the pre-conditioner for the Schur complement system. [Schur matrix (HYPRE)](#schurhypre)
# * Full matrix with AMGX used as the pre-conditioner for the full system. [Full matrix (AMGX)](#fullamgx)
# * Schur matrix with AMGX used as the pre-conditioner for the Schur complement system. [Schur matrix (AMGX)](#schuramgx)
#
# We also include comparisions between HYPRE and the Schur matrix approach [here](#comparisons).
# <hr style="border-width:3px; border-color:coral"/>

# %% [markdown]
# ## Read in spreadsheet data
#
# This is set up to read the "div 2" data.  To read data from other runs, change the four statements below from   "(2)" to "(3)" or "(4)".
#
# **Note:** Data may not yet be available in the spreadsheet for these other cases.

# %%
# %reload_ext autoreload
# %autoreload 2

from results_output import *

# %%
timing_results = pd.read_excel("Timing_results.xlsx",sheet_name=None)
div_factor = 2
df_full_hypre  = timing_results["full_hypre ({:d})".format(div_factor)]
df_schur_hypre = timing_results["schur_hypre ({:d})".format(div_factor)]
df_full_amgx   = timing_results["full_amgx ({:d})".format(div_factor)]
df_schur_amgx  = timing_results["schur_amgx ({:d})".format(div_factor)]


# For HYPRE results
cols_setup_hypre = ['matrix_setup','hypre_setup']
df_full_hypre['complete_setup'] = df_full_hypre[cols_setup_hypre].sum(axis=1)
df_schur_hypre['complete_setup'] = df_schur_hypre[cols_setup_hypre].sum(axis=1)

# Fix AMGX results
cols_setup_amgx = ['matrix_setup','amgx_setup']
df_full_amgx['complete_setup'] = df_full_amgx[cols_setup_amgx].sum(axis=1)  # Should equal linsys_setup
df_schur_amgx['complete_setup'] = df_schur_amgx[cols_setup_amgx].sum(axis=1)

cols_solve_full =['linsolve']
cols_solve_schur = ['linsolve','patch_solve']

# %% [markdown]
# <a id='fullhypre'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Full matrix (HYPRE)
# <hr style="border-width:3px; border-color:coral"/>

# %%
import seaborn as sns
cm = sns.light_palette("blue", as_cmap=True)

styler = print_table(df_full_hypre,display_table=False);

# Apply gradient coloring;  use low=, high= to extend domain to [xmin-low*(xmax-xmin),xmax+high*(xmax-xmin)]; defaults=0
styler.background_gradient(subset=['complete_solve','complete_setup'],cmap=cm,low=0,high=0.7)
# Out:
# <style  type="text/css" >
#     #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col4 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col5 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col6 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col7 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col8 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col9 {
#             width:  100px;
#             background-color:  #5e5eff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow0_col10 {
#             width:  100px;
#             background-color:  #d9d9ff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col4 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col5 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col6 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col7 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col8 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col9 {
#             width:  100px;
#             background-color:  #a5a5ff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow1_col10 {
#             width:  100px;
#             background-color:  #5e5eff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col4 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col5 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col6 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col7 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col8 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col9 {
#             width:  100px;
#             background-color:  #c3c3ff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow2_col10 {
#             width:  100px;
#             background-color:  #a2a2ff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col4 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col5 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col6 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col7 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col8 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col9 {
#             width:  100px;
#             background-color:  #c7c7ff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow3_col10 {
#             width:  100px;
#             background-color:  #ceceff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col4 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col5 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col6 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col7 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col8 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col9 {
#             width:  100px;
#             background-color:  #cacaff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow4_col10 {
#             width:  100px;
#             background-color:  #dfdfff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col4 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col5 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col6 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col7 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col8 {
#             width:  100px;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col9 {
#             width:  100px;
#             background-color:  #e5e5ff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow5_col10 {
#             width:  100px;
#             background-color:  #e5e5ff;
#         }    #T_a1b6a1d0_2995_11e8_8c83_784f439ce51drow6_col0 {
#             width:  100px;
#             width:  50px;
#             text-a

# %% [markdown]
# ## Full matrix (HYPRE) : Setup

# %%
barh_plot(df_full_hypre,cols_setup_hypre)
plt.title('Full matrix (setup)',fontsize=16);
set_xticks(20,5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Solve

# %%
bar_plot(df_full_hypre,cols_solve_full)
plt.title('Full solve (HYPRE)',fontsize=16);
set_xticks(5,2.5)
plt.xlim([0,20])
plt.xlabel('Time (seconds)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Strong scaling

# %%
strong_scaling(df_full_hypre,field='complete_solve')
plt.title('Full matrix (HYPRE) : Solve');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Efficiency

# %%
efficiency(df_full_hypre,'complete_solve')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='schurhypre'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Schur matrix (HYPRE)
# <hr style="border-width:3px; border-color:coral"/>

# %%
styler = print_table(df_schur_hypre,display_table=False);

# Apply gradient coloring;  use low=, high= to extend domain to [xmin-low*(xmax-xmin),xmax+high*(xmax-xmin)]; defaults=0
styler.background_gradient(subset=['complete_solve','complete_setup'],cmap=cm,low=0,high=0.5)
# Out:
# <style  type="text/css" >
#     #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col4 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col5 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col6 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col7 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col8 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col9 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col10 {
#             width:  100px;
#             background-color:  #4d4dff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow0_col11 {
#             width:  100px;
#             background-color:  #4d4dff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col4 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col5 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col6 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col7 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col8 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col9 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col10 {
#             width:  100px;
#             background-color:  #8a8aff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow1_col11 {
#             width:  100px;
#             background-color:  #9595ff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col4 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col5 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col6 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col7 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col8 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col9 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col10 {
#             width:  100px;
#             background-color:  #9595ff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow2_col11 {
#             width:  100px;
#             background-color:  #b8b8ff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col4 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col5 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col6 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col7 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col8 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col9 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col10 {
#             width:  100px;
#             background-color:  #8b8bff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow3_col11 {
#             width:  100px;
#             background-color:  #ccccff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col4 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col5 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col6 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col7 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col8 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col9 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col10 {
#             width:  100px;
#             background-color:  #d6d6ff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow4_col11 {
#             width:  100px;
#             background-color:  #d9d9ff;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow5_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow5_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow5_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow5_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow5_col4 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow5_col5 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow5_col6 {
#             width:  100px;
#         }    #T_a22bb236_2995_11e8_837c_784f439ce51drow5_col7 {
#             width:  100px;
#         }    #T_a22bb236_2995

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup
#
# Use HYPRE to solve the Schur complement system

# %%
barh_plot(df_schur_hypre,cols_setup_hypre)
plt.title('Schur matrix (HYPRE) : Setup',fontsize=16);
set_xticks(2,1,fmt='{:.1f}'.format)
plt.xlim([0,7.5]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Strong scaling (setup)

# %%
strong_scaling(df_schur_hypre,field='complete_setup')
plt.title('Schur matrix (HYPRE) : Strong scaling (setup)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup

# %%
efficiency(df_schur_hypre,'complete_setup')
plt.title('Schur matrix (HYPRE) : Efficiency (%)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Solve

# %%
barh_plot(df_schur_hypre,cols_solve_schur)

plt.title('Schur matrix (HYPRE) : solve',fontsize=16);
set_xticks(2,1,fmt='{:.1f}'.format)

plt.xlim([0,7.5]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Strong scaling (solve)

# %%
strong_scaling(df_schur_hypre,field='complete_solve')
plt.title('Schur matrix (HYPRE) : Strong scaling (solve)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup vs solve time

# %%
bar_plot(df_schur_hypre,['complete_solve','complete_setup'])

plt.xlim([0,7.5])
plt.title('Schur matrix (HYPRE) : Setup vs. solve',fontsize=16);
set_xticks(2,1)
plt.grid(b=True,which='major')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Efficiency

# %%
efficiency(df_schur_hypre,'complete_solve')
plt.title('Schur matrix (HYPRE) : Efficiency (solve)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='fullamgx'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Full matrix (AMGX)
# <hr style="border-width:3px; border-color:coral"/>
#
# Use AMGX to solve the full matrix system

# %%
print_table(df_full_amgx);
# Out:
# <style  type="text/css" >
#     #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col4 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col5 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col6 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col7 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col8 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col9 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col10 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col4 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col5 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col6 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col7 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col8 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col9 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col10 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col4 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col5 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col6 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col7 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col8 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col9 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow2_col10 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col4 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col5 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col6 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col7 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col8 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col9 {
#             width:  100px;
#         }    #T_a2c0736c_2995_11e8_b9e5_784f439ce51drow3_col10 {
#             width:  100px;
#         }</style>
# <table id="T_a2c0736c_2995_11e8_b9e5_784f439ce51d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >p</th>
#         <th class="col_heading level0 col1" >iterations</th>
#         <th class="col_heading level0 col2" >residual</th>
#         <th class="col_heading level0 col3" >error</th>
#         <th class="col_heading level0 col4" >domain_init</th>
#         <th class="col_heading level0 col5" >matrix_setup</th>
#         <th class="col_heading level0 col6" >amgx_setup</th>
#         <th class="col_heading level0 col7" >linsys_setup</th>
#         <th class="col_heading level0 col8" >linsolve</th>
#         <th class="col_heading level0 col9" >complete_solve</th>
#         <th class="col_heading level0 col10" >complete_setup</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a2c0736c_2995_11e8_b9e5_784f439ce51dlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col0" class="data row0 col0" >1</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col1" class="data row0 col1" >39</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col2" class="data row0 col2" >5.83e-11</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col3" class="data row0 col3" >9.23e-04</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col4" class="data row0 col4" >0.5904</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col5" class="data row0 col5" >0.8642</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col6" class="data row0 col6" >1.1431</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col7" class="data row0 col7" >2.0073</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col8" class="data row0 col8" >1.4629</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col9" class="data row0 col9" >1.4629</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow0_col10" class="data row0 col10" >2.0073</td>
#     </tr>    <tr>
#         <th id="T_a2c0736c_2995_11e8_b9e5_784f439ce51dlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col0" class="data row1 col0" >2</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col1" class="data row1 col1" >37</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col2" class="data row1 col2" >5.94e-12</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col3" class="data row1 col3" >9.23e-04</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col4" class="data row1 col4" >0.3186</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col5" class="data row1 col5" >0.5233</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col6" class="data row1 col6" >2.2336</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_col7" class="data row1 col7" >2.7569</td>
#         <td id="T_a2c0736c_2995_11e8_b9e5_784f439ce51drow1_c

# %% [markdown]
# ## Full matrix (AMGX) : Setup

# %%
barh_plot(df_full_amgx,cols_setup_amgx)
plt.title('Full matrix (AMGX) : Setup',fontsize=16)
set_xticks(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (AMGX) : Solve

# %%
barh_plot(df_full_amgx,cols_solve_full)

plt.title('Full matrix (AMGX) : solve',fontsize=16)
set_xticks(0.5,0.25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (AMGX) : Setup vs. solve

# %%
bar_plot(df_full_amgx,['complete_solve','complete_setup'])
plt.title('Full matrix (AMGX) : Setup vs. solve',fontsize=16)
set_xticks(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (AMGX ) : Efficiency

# %%
efficiency(df_full_amgx,'complete_solve')
plt.title('Full matrix (AMGX) : Efficiency (solve)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='schuramgx'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Schur matrix (AMGX)
# <hr style="border-width:3px; border-color:coral"/>
#
# Solve the Schur complement system using AMGX

# %%
print_table(df_schur_amgx);
# Out:
# <style  type="text/css" >
#     #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col4 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col5 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col6 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col7 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col8 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col9 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col10 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow0_col11 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col4 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col5 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col6 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col7 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col8 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col9 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col10 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow1_col11 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col4 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col5 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col6 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col7 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col8 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col9 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col10 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow2_col11 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col4 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col5 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col6 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col7 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col8 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col9 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col10 {
#             width:  100px;
#         }    #T_a30ad830_2995_11e8_9034_784f439ce51drow3_col11 {
#             width:  100px;
#         }</style>
# <table id="T_a30ad830_2995_11e8_9034_784f439ce51d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >p</th>
#         <th class="col_heading level0 col1" >iterations</th>
#         <th class="col_heading level0 col2" >residual</th>
#         <th class="col_heading level0 col3" >error</th>
#         <th class="col_heading level0 col4" >domain_init</th>
#         <th class="col_heading level0 col5" >matrix_setup</th>
#         <th class="col_heading level0 col6" >amgx_setup</th>
#         <th class="col_heading level0 col7" >linsys_setup</th>
#         <th class="col_heading level0 col8" >linsolve</th>
#         <th class="col_heading level0 col9" >patch_solve</th>
#         <th class="col_heading level0 col10" >complete_solve</th>
#         <th class="col_heading level0 col11" >complete_setup</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a30ad830_2995_11e8_9034_784f439ce51dlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col0" class="data row0 col0" >1</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col1" class="data row0 col1" >17</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col2" class="data row0 col2" >1.37e-11</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col3" class="data row0 col3" >9.23e-04</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col4" class="data row0 col4" >0.5856</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col5" class="data row0 col5" >1.4475</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col6" class="data row0 col6" >1.5284</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col7" class="data row0 col7" >2.9760</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col8" class="data row0 col8" >0.3923</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col9" class="data row0 col9" >0.0602</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col10" class="data row0 col10" >0.4525</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow0_col11" class="data row0 col11" >2.9759</td>
#     </tr>    <tr>
#         <th id="T_a30ad830_2995_11e8_9034_784f439ce51dlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow1_col0" class="data row1 col0" >2</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow1_col1" class="data row1 col1" >17</td>
#         <td id="T_a30ad830_2995_11e8_9034_784f439ce51drow1_col2" class="data row1 col2" >1.35e-11</td>
#         <td id="T_a30ad830_2995_11e8

# %% [markdown]
# ## Schur matrix (AMGX) : Setup
#
# Use AMGX to solve the Schur complement system

# %%
barh_plot(df_schur_amgx,cols_setup_amgx)
plt.title('Schur matrix (AMGX) : Setup',fontsize=16);
set_xticks(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (AMGX) : Solve

# %%
barh_plot(df_schur_amgx,cols_solve_schur)

plt.title('Schur matrix (AMGX) : solve',fontsize=16);
set_xticks(0.125,0.125/2,fmt='{:.3f}'.format)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (AMGX) : Setup vs. solve

# %%
bar_plot(df_schur_amgx,['complete_solve','complete_setup'])
plt.title('Schur matrix (AMGX) : Setup vs. solve',fontsize=16);
set_xticks(2.5,1.25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (AMGX) : Efficiency

# %%
efficiency(df_schur_amgx,'complete_solve')
plt.title('Schur matrix (AMGX) : Efficiency');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='comparisons'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Comparisons between full and Schur systems
# <hr style="border-width:3px; border-color:coral"/>

# %%
panel = pd.Panel({'Full (HYPRE)' : df_full_hypre, 'Schur (HYPRE)' : df_schur_hypre,
                 'Full (AMGX)' : df_full_amgx, 'Schur (AMGX)' : df_schur_amgx})
procs = df_full_hypre['p']

# %% [markdown]
# ## Comparisons : Setup

# %%
df_setup = panel.minor_xs('complete_setup')
df_setup.insert(0,'p',procs)
df_setup
# Out:
#     p  Full (AMGX)  Full (HYPRE)  Schur (AMGX)  Schur (HYPRE)
# 0   1     2.007304      3.324172      2.975945       2.536331
# 1   2     2.756896     28.394316      1.572832       1.416045
# 2   4     2.294107     14.478820      0.990130       0.870671
# 3   8     1.803886      5.381842      1.087095       0.565261
# 4  16          NaN      1.863866           NaN       0.377011
# 5  32          NaN      0.750696           NaN       0.235410
# 6  64          NaN      0.570400           NaN       0.175524

# %%
df_setup.plot(x='p',logx=True,logy=True,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Setup time',fontsize=16);
fix_xticks(df_setup['p'].values)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['Schur (AMGX)', 'Full (AMGX)', 'Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_setup,cols=cols)
plt.title("Timing (setup)", fontsize=16);
set_xticks(2,1)
# Out:
# /usr/local/Anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['Schur (AMGX)', 'Full (AMGX)', 'Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_setup,cols=cols)
plt.title("Timing (setup)", fontsize=16);
# Out:
# /usr/local/Anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Comparisons : Solve

# %%
df_solve = panel.minor_xs('complete_solve')
df_solve.insert(0,'p',procs)
df_solve
# Out:
#     p  Full (AMGX)  Full (HYPRE)  Schur (AMGX)  Schur (HYPRE)
# 0   1     1.462942     16.062464      0.452522       6.370383
# 1   2     1.157454     10.720535      0.337321       3.965723
# 2   4     0.899815      8.425555      0.291192       3.488669
# 3   8     1.293654      8.153320      0.297567       3.890590
# 4  16          NaN      7.838561           NaN       0.928360
# 5  32          NaN      5.909508           NaN       0.479916
# 6  64          NaN      5.784827           NaN       0.305838

# %%
cols = ['p','Full (HYPRE)','Schur (HYPRE)','Full (AMGX)','Schur (AMGX)']
cols = ['p','Full (HYPRE)','Schur (HYPRE)']
df_solve[cols].plot(x='p',logx=True,logy=False,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Solve time (HYPRE)',fontsize=16);
fix_xticks(df_solve['p'].values)
# Out:
# /usr/local/Anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['p','Full (AMGX)','Schur (AMGX)']
df_solve[cols].plot(x='p',logx=True,logy=False,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Solve time (AMGX)',fontsize=16);
fix_xticks(df_solve['p'].values)
# Out:
# /usr/local/Anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">

# %%
cols=['Full (HYPRE)','Schur (HYPRE)','Full (AMGX)','Schur (AMGX)']
cols = ['Schur (AMGX)', 'Full (AMGX)', 'Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_solve,cols=cols)
plt.title("Timing (solve)", fontsize=16);
set_xticks(5,2.5)
# Out:
# /usr/local/Anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">
