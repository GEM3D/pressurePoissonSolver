# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <hr style="border-width:3px; border-color:coral"/>
# # Timing results for pressure Poisson solver
# <hr style="border-width:3px; border-color:coral"/>
#
#
# Two solver types are reported. In the full matrix system, the discretized system $A\mathbf x = \mathbf b$ is solved. In the Schur complement system, a linear system for the interface values is solved, and a fast FFT-based solver is used for patch solves.  In either the Full or the Schur approaches, GMRES is used as the basic solver (from HYPRE?) along with an an AMG pre-conditioner from HYPRE (BoomerAMG).
#
# Both simulations reported below are then
# * Full matrix with HYPRE used as the pre-conditioner for the full system. [Full matrix (HYPRE)](#fullhypre)
# * Schur matrix with HYPRE used as the pre-conditioner for the Schur complement system. [Schur matrix (HYPRE)](#schurhypre)
#
# We also include comparisions between HYPRE and the Schur matrix approach [here](#comparisons).
# <hr style="border-width:3px; border-color:coral"/>

# %% [markdown]
# ## Read in spreadsheet data
#
# This is set up to read the "div 2" data.  To read data from other runs, change the four statements below from   "(2)" to "(3)" or "(4)".
#
# **Note:** Data may not yet be available in the spreadsheet for these other cases.

# %%
# %reload_ext autoreload
# %autoreload 2

from results_output import *

# %%
timing_results = pd.read_excel("Timing_results.xlsx",sheet_name=None)
div_factor = 3
df_full_hypre  = timing_results["full_hypre ({:d})".format(div_factor)]
df_schur_hypre = timing_results["schur_hypre ({:d})".format(div_factor)]


# For HYPRE results
cols_setup_hypre = ['matrix_setup','hypre_setup']
df_full_hypre['complete_setup'] = df_full_hypre[cols_setup_hypre].sum(axis=1)
df_schur_hypre['complete_setup'] = df_schur_hypre[cols_setup_hypre].sum(axis=1)


cols_solve_full =['linsolve']
cols_solve_schur = ['linsolve','patch_solve']

# %% [markdown]
# <a id='fullhypre'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Full matrix (HYPRE)
# <hr style="border-width:3px; border-color:coral"/>

# %%
import seaborn as sns
cm = sns.light_palette("blue", as_cmap=True)

styler = print_table(df_full_hypre,display_table=False);

# Apply gradient coloring;  use low=, high= to extend domain to [xmin-low*(xmax-xmin),xmax+high*(xmax-xmin)]; defaults=0
styler.background_gradient(subset=['complete_solve','complete_setup'],cmap=cm,low=0,high=0.7)
# Out:
# <style  type="text/css" >
#     #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col4 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col5 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col6 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col7 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col8 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col9 {
#             width:  100px;
#             background-color:  #5e5eff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col10 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row0_col11 {
#             width:  100px;
#             background-color:  #e2e2ff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col4 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col5 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col6 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col7 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col8 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col9 {
#             width:  100px;
#             background-color:  #9e9eff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col10 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row1_col11 {
#             width:  100px;
#             background-color:  #5e5eff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col4 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col5 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col6 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col7 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col8 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col9 {
#             width:  100px;
#             background-color:  #bcbcff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col10 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row2_col11 {
#             width:  100px;
#             background-color:  #a6a6ff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col4 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col5 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col6 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col7 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col8 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col9 {
#             width:  100px;
#             background-color:  #d2d2ff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col10 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row3_col11 {
#             width:  100px;
#             background-color:  #ceceff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col4 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col5 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col6 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col7 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col8 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col9 {
#             width:  100px;
#             background-color:  #d9d9ff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col10 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row4_col11 {
#             width:  100px;
#             background-color:  #dfdfff;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row5_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row5_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row5_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row5_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row5_col4 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row5_col5 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row5_col6 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc_11e8_aa5f_000c29b65823row5_col7 {
#             width:  100px;
#         }    #T_4d3673a0_3bfc

# %% [markdown]
# ## Full matrix (HYPRE) : Setup

# %%
barh_plot(df_full_hypre,cols_setup_hypre)
plt.title('Full matrix (setup)',fontsize=16);
set_xticks(20,5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Solve

# %%
bar_plot(df_full_hypre,cols_solve_full)
plt.title('Full solve (HYPRE)',fontsize=16);
set_xticks(5,2.5)
plt.xlim([0,20])
plt.xlabel('Time (seconds)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Strong scaling

# %%
strong_scaling(df_full_hypre,field='complete_solve')
plt.title('Full matrix (HYPRE) : Solve');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full matrix (HYPRE) : Efficiency

# %%
efficiency(df_full_hypre,'complete_solve')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='schurhypre'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Schur matrix (HYPRE)
# <hr style="border-width:3px; border-color:coral"/>

# %%
styler = print_table(df_schur_hypre,display_table=False);

# Apply gradient coloring;  use low=, high= to extend domain to [xmin-low*(xmax-xmin),xmax+high*(xmax-xmin)]; defaults=0
styler.background_gradient(subset=['complete_solve','complete_setup'],cmap=cm,low=0,high=0.5)
# Out:
# <style  type="text/css" >
#     #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col4 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col5 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col6 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col7 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col8 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col9 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col10 {
#             width:  100px;
#             background-color:  #4d4dff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row0_col11 {
#             width:  100px;
#             background-color:  #4d4dff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col4 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col5 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col6 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col7 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col8 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col9 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col10 {
#             width:  100px;
#             background-color:  #b0b0ff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row1_col11 {
#             width:  100px;
#             background-color:  #a4a4ff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col4 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col5 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col6 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col7 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col8 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col9 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col10 {
#             width:  100px;
#             background-color:  #cacaff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row2_col11 {
#             width:  100px;
#             background-color:  #c1c1ff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col4 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col5 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col6 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col7 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col8 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col9 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col10 {
#             width:  100px;
#             background-color:  #d7d7ff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row3_col11 {
#             width:  100px;
#             background-color:  #d2d2ff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col4 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col5 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col6 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col7 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col8 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col9 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col10 {
#             width:  100px;
#             background-color:  #dadaff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row4_col11 {
#             width:  100px;
#             background-color:  #dbdbff;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row5_col0 {
#             width:  100px;
#             width:  50px;
#             text-align:  right;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row5_col1 {
#             width:  100px;
#             width:  30px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row5_col2 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row5_col3 {
#             width:  100px;
#             width:  80px;
#             text-align:  right;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row5_col4 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row5_col5 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row5_col6 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc_11e8_aa5f_000c29b65823row5_col7 {
#             width:  100px;
#         }    #T_4d3673a1_3bfc

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup
#
# Use HYPRE to solve the Schur complement system

# %%
barh_plot(df_schur_hypre,cols_setup_hypre)
plt.title('Schur matrix (HYPRE) : Setup',fontsize=16);
set_xticks(2,1,fmt='{:.1f}'.format)
plt.xlim([0,7.5]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Strong scaling (setup)

# %%
strong_scaling(df_schur_hypre,field='complete_setup')
plt.title('Schur matrix (HYPRE) : Strong scaling (setup)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup

# %%
efficiency(df_schur_hypre,'complete_setup')
plt.title('Schur matrix (HYPRE) : Efficiency (%)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Solve

# %%
barh_plot(df_schur_hypre,cols_solve_schur)

plt.title('Schur matrix (HYPRE) : solve',fontsize=16);
set_xticks(2,1,fmt='{:.1f}'.format)

plt.xlim([0,7.5]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Strong scaling (solve)

# %%
strong_scaling(df_schur_hypre,field='complete_solve')
plt.title('Schur matrix (HYPRE) : Strong scaling (solve)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Setup vs solve time

# %%
bar_plot(df_schur_hypre,['complete_solve','complete_setup'])

plt.xlim([0,7.5])
plt.title('Schur matrix (HYPRE) : Setup vs. solve',fontsize=16);
set_xticks(2,1)
plt.grid(b=True,which='major')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Schur matrix (HYPRE) : Efficiency

# %%
efficiency(df_schur_hypre,'complete_solve')
plt.title('Schur matrix (HYPRE) : Efficiency (solve)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id='comparisons'></a>
# <hr style="border-width:3px; border-color:coral"/>
# # Comparisons between full and Schur systems
# <hr style="border-width:3px; border-color:coral"/>

# %%
panel = pd.Panel({'Full (HYPRE)' : df_full_hypre, 'Schur (HYPRE)' : df_schur_hypre})
procs = df_full_hypre['p']

# %% [markdown]
# ## Comparisons : Setup

# %%
df_setup = panel.minor_xs('complete_setup')
df_setup.insert(0,'p',procs)
df_setup
# Out:
#     p  Full (HYPRE)  Schur (HYPRE)
# 0   1     14.010388      10.556899
# 1   2    393.920946       4.780893
# 2   4    186.202727       2.914690
# 3   8     73.028272       1.765250
# 4  16     22.331174       1.187788
# 5  32      6.736404       0.628790
# 6  64      2.992371       0.434312

# %%
df_setup.plot(x='p',logx=True,logy=True,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Setup time',fontsize=16);
fix_xticks(df_setup['p'].values)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_setup,cols=cols)
plt.title("Timing (setup)", fontsize=16);
set_xticks(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols = ['Schur (HYPRE)', 'Full (HYPRE)']
bar_plot(df_setup,cols=cols)
plt.title("Timing (setup)", fontsize=16);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Comparisons : Solve

# %%
df_solve = panel.minor_xs('complete_solve')
df_solve.insert(0,'p',procs)
df_solve
# Out:
#     p  Full (HYPRE)  Schur (HYPRE)
# 0   1     56.467347      29.654561
# 1   2     32.860442      11.239216
# 2   4     21.381026       6.280635
# 3   8     13.034791       3.817631
# 4  16     10.552411       3.433647
# 5  32      5.588668       1.983752
# 6  64     11.179005       1.095311

# %%
cols = ['p','Full (HYPRE)','Schur (HYPRE)']
df_solve[cols].plot(x='p',logx=True,logy=False,style='.-',markersize=10)
plt.xlabel('p')
plt.ylabel('Time (seconds)')
plt.title('Solve time (HYPRE)',fontsize=16);
fix_xticks(df_solve['p'].values)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cols=['Full (HYPRE)','Schur (HYPRE)']
bar_plot(df_solve,cols=cols)
plt.title("Timing (solve)", fontsize=16);
set_xticks(5,2.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
